# %%
import glob
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy

sns.set_context('paper', font_scale=1)
plt.rcParams['figure.figsize'] = (12, 8)

# %%
# %matplotlib inline

# %%
pd.__version__
# Out:
# u'0.18.1'

# %%
data = pd.read_csv("../testing/deno.csv")

# %%
print data.head()
# Out:
#    generation                   populationName  \
# 0           0  DirectlyEncodedNetworkOperators
# 1           0  DirectlyEncodedNetworkOperators
# 2           0  DirectlyEncodedNetworkOperators
# 3           0  DirectlyEncodedNetworkOperators
# 4           0  DirectlyEncodedNetworkOperators
#
#                              individual  parent1  parent2      fitness  \
# 0  51c62776-57ed-424b-9adc-1e385db9056d      NaN      NaN    88.923876
# 1  446040da-6cb2-43f1-ad9e-b8b47311e79c      NaN      NaN  1005.574472
# 2  9014112d-0b75-4277-af08-0264db0aaf6c      NaN      NaN   924.887604
# 3  6b41823b-4621-4208-9208-67e75a0822c9      NaN      NaN  1036.005058
# 4  1fa30eeb-8ece-4112-a34a-291725de55bb      NaN      NaN   637.527827
#
#      loci-0    loci-1    loci-2    loci-3    loci-4    loci-5    loci-6  \
# 0 -0.299332 -2.538964  1.246521  2.806349 -1.483831 -2.836219  2.411473
# 1  0.929273 -0.489442 -1.777851 -1.185366 -1.496241 -1.275152 -0.293770
# 2 -0.733280  1.491518  0.979649 -1.292855  2.106826 -0.711774  1.882666
# 3 -0.981042  1.453700  0.975129 -2.160733 -1.550924 -1.358888 -0.371585
# 4 -1.766740 -1.433070  2.185205 -0.364087  0.760899 -1.412996 -0.694660
#
#      loci-7    loci-8    loci-9
# 0 -1.546247  1.810968 -4.700728
# 1 -0.694715 -2.364596 -1.495998
# 2  2.970826 -1.978569 -3.645635
# 3 -1.183718  2.196986 -3.831245
# 4 -2.543431 -0.024305 -4.544934

# %%
data.describe()
# Out:
# /Users/liara/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>generation</th>
#       <th>parent1</th>
#       <th>parent2</th>
#       <th>fitness</th>
#       <th>loci-0</th>
#       <th>loci-1</th>
#       <th>loci-2</th>
#       <th>loci-3</th>
#       <th>loci-4</th>
#       <th>loci-5</th>
#       <th>loci-6</th>
#       <th>loci-7</th>
#       <th>loci-8</th>
#       <th>loci-9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>4200.000000</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#       <td>4200.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>20.500000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>10171.697029</td>
#       <td>2.469098</td>
#       <td>2.463403</td>
#       <td>2.462557</td>
#       <td>2.638652</td>
#       <td>-1.569363</td>
#       <td>-2.090456</td>
#       <td>2.205524</td>
#       <td>0.521972</td>
#       <td>0.938317</td>
#       <td>-5.833705</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>12.122362</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>3637.668529</td>
#       <td>0.639606</td>
#       <td>0.793384</td>
#       <td>0.844952</td>
#       <td>0.802990</td>
#       <td>0.360228</td>
#       <td>0.450994</td>
#       <td>0.589909</td>
#       <td>0.384460</td>
#       <td>0.576891</td>
#       <td>0.810696</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-13.323312</td>
#       <td>-2.980836</td>
#       <td>-2.985665</td>
#       <td>-2.990587</td>
#       <td>-2.956080</td>
#       <td>-2.980068</td>
#       <td>-2.958165</td>
#       <td>-2.950929</td>
#       <td>-2.850789</td>
#       <td>-2.928982</td>
#       <td>-6.918950</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>10.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>10466.827840</td>
#       <td>2.572101</td>
#       <td>2.640138</td>
#       <td>2.643048</td>
#       <td>2.797337</td>
#       <td>-1.595525</td>
#       <td>-2.160903</td>
#       <td>2.114361</td>
#       <td>0.578013</td>
#       <td>1.016134</td>
#       <td>-6.029718</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>20.500000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>11911.160197</td>
#       <td>2.608632</td>
#       <td>2.642226</td>
#       <td>2.643048</td>
#       <td>2.816191</td>
#       <td>-1.595525</td>
#       <td>-2.147420</td>
#       <td>2.322349</td>
#       <td>0.578013</td>
#       <td>1.016134</td>
#       <td>-5.968147</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>31.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>12270.354818</td>
#       <td>2.623774</td>
#       <td>2.642226</td>
#       <td>2.645929</td>
#       <td>2.816191</td>
#       <td>-1.595525</td>
#       <td>-2.147420</td>
#       <td>2.426655</td>
#       <td>0.578013</td>
#       <td>1.040296</td>
#       <td>-5.968147</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>41.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>13725.953020</td>
#       <td>2.935481</td>
#       <td>2.972871</td>
#       <td>2.990070</td>
#       <td>2.976644</td>
#       <td>2.825867</td>
#       <td>2.952386</td>
#       <td>2.897027</td>
#       <td>2.970826</td>
#       <td>2.994711</td>
#       <td>-1.043153</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ax = sns.boxplot(x='generation', y="loci-9", data=data)
plt.savefig("test.svg")
plt.show()
